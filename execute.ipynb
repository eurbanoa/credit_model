# %%
from DataProcessor import DataProcs

# %%
# Step 2: Initialize the DataProcs object
processor = DataProcs()

cleaned_data = processor.master(clean=True, impute_method="median")

# Display the first five rows
print(cleaned_data.head())  # This avoids Snowflake’s SQL conversion and directly views the data
# Out:
# Connected to Snowflake
# Loading data from Snowflake...
# Cleaning header row...
# WARNING:snowflake.snowpark.modin.plugin.utils.warning_message:The current operation leads to materialization and can be slow if the data is large!
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Step 2: Initialize the DataProcs object
#       2 processor = DataProcs()
# ----> 4 cleaned_data = processor.master(clean=True, impute_method="median")
#       6 # Display the first five rows
#       7 print(cleaned_data.head())
#
# File ~/Data_Proyects/credit_snowflake/DataProcessor.py:177, in DataProcs.master(self, clean, impute_method)
#     175 #self.__create_dummies__()
#     176 self.__convert_target_var__()
# --> 177 self.__convert_OBS_DATE__()
#     179 return self.cleaned_data
#
# ...
